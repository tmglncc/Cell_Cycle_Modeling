# %% [markdown]
# # Plotting the temporal evolution of the number of tumor cells

# %% [markdown]
# ## Import libraries

# %%
#  add Python-loader repo to the path 
import sys
sys.path.insert(0, '../Python-loader/')
from pyMCDS import pyMCDS

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## List *.xml* output files

# %%
## Type pyMCDS. and hit the tab key to see methods 

# !ls ./output/*.xml
# Out:
# ./output/final.xml
# ./output/initial.xml
# ./output/output00000000.xml
# ./output/output00000001.xml
# ./output/output00000002.xml
# ./output/output00000003.xml
# ./output/output00000004.xml
# ./output/output00000005.xml
# ./output/output00000006.xml
# ./output/output00000007.xml
# ./output/output00000008.xml
# ./output/output00000009.xml
# ./output/output00000010.xml
# ./output/output00000011.xml
# ./output/output00000012.xml
# ./output/output00000013.xml
# ./output/output00000014.xml
# ./output/output00000015.xml
# ./output/output00000016.xml
# ./output/output00000017.xml
# ./output/output00000018.xml
# ./output/output00000019.xml
# ./output/output00000020.xml
# ./output/output00000021.xml
# ./output/output00000022.xml
# ./output/output00000023.xml
# ./output/output00000024.xml
# ./output/output00000025.xml
# ./output/output00000026.xml
# ./output/output00000027.xml
# ./output/output00000028.xml
# ./output/output00000029.xml
# ./output/output00000030.xml
# ./output/output00000031.xml
# ./output/output00000032.xml
# ./output/output00000033.xml
# ./output/output00000034.xml
# ./output/output00000035.xml
# ./output/output00000036.xml
# ./output/output00000037.xml
# ./output/output00000038.xml
# ./output/output00000039.xml
# ./output/output00000040.xml
# ./output/output00000041.xml
# ./output/output00000042.xml
# ./output/output00000043.xml
# ./output/output00000044.xml
# ./output/output00000045.xml
# ./output/output00000046.xml
# ./output/output00000047.xml
# ./output/output00000048.xml
# ./output/output00000049.xml
# ./output/output00000050.xml
# ./output/output00000051.xml
# ./output/output00000052.xml
# ./output/output00000053.xml
# ./output/output00000054.xml
# ./output/output00000055.xml
# ./output/output00000056.xml
# ./output/output00000057.xml
# ./output/output00000058.xml
# ./output/output00000059.xml
# ./output/output00000060.xml
# ./output/output00000061.xml
# ./output/output00000062.xml
# ./output/output00000063.xml
# ./output/output00000064.xml
# ./output/output00000065.xml
# ./output/output00000066.xml
# ./output/output00000067.xml
# ./output/output00000068.xml
# ./output/output00000069.xml
# ./output/output00000070.xml
# ./output/output00000071.xml
# ./output/output00000072.xml
# ./output/output00000073.xml
# ./output/output00000074.xml
# ./output/output00000075.xml
# ./output/output00000076.xml
# ./output/output00000077.xml
# ./output/output00000078.xml
# ./output/output00000079.xml
# ./output/output00000080.xml
# ./output/output00000081.xml
# ./output/output00000082.xml
# ./output/output00000083.xml
# ./output/output00000084.xml
# ./output/output00000085.xml
# ./output/output00000086.xml
# ./output/output00000087.xml
# ./output/output00000088.xml
# ./output/output00000089.xml
# ./output/output00000090.xml
# ./output/output00000091.xml
# ./output/output00000092.xml
# ./output/output00000093.xml
# ./output/output00000094.xml
# ./output/output00000095.xml
# ./output/output00000096.xml
# ./output/output00000097.xml
# ./output/output00000098.xml
# ./output/output00000099.xml
# ./output/output00000100.xml
# ./output/output00000101.xml
# ./output/output00000102.xml
# ./output/output00000103.xml
# ./output/output00000104.xml
# ./output/output00000105.xml
# ./output/output00000106.xml
# ./output/output00000107.xml
# ./output/output00000108.xml
# ./output/output00000109.xml
# ./output/output00000110.xml
# ./output/output00000111.xml
# ./output/output00000112.xml
# ./output/output00000113.xml
# ./output/output00000114.xml
# ./output/output00000115.xml
# ./output/output00000116.xml
# ./output/output00000117.xml
# ./output/output00000118.xml
# ./output/output00000119.xml
# ./output/output00000120.xml
# ./output/PhysiCell_settings_Ki67_Basic_without_o2_apop_nec.xml

# %% [markdown]
# ## Read an *.xml* output file

# %%
mcds = pyMCDS('final.xml', 'output')
# Out:
# Reading output/final.xml
# Reading output/initial_mesh0.mat
# Reading output/final_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/final_cells.mat

# %% [markdown]
# ## Print information about the file

# %%
print(mcds.get_time())  # what simulation time is saved here?
# Out:
# 7200.01

# %%
print(mcds.get_cell_variables()) # what data are saved in the cells?
# Out:
# ['ID', 'position_x', 'position_y', 'position_z', 'total_volume', 'cell_type', 'cycle_model', 'current_phase', 'elapsed_time_in_phase', 'nuclear_volume', 'cytoplasmic_volume', 'fluid_fraction', 'calcified_fraction', 'orientation_x', 'orientation_y', 'orientation_z', 'polarity', 'velocity_x', 'velocity_y', 'velocity_z', 'pressure', 'number_of_nuclei', 'damage', 'total_attack_time', 'contact_with_basement_membrane', 'current_cycle_phase_exit_rate', 'dead', 'current_death_model', 'death_rates_0', 'death_rates_1', 'cytoplasmic_biomass_change_rate', 'nuclear_biomass_change_rate', 'fluid_change_rate', 'calcification_rate', 'target_solid_cytoplasmic', 'target_solid_nuclear', 'target_fluid_fraction', 'radius', 'nuclear_radius', 'surface_area', 'cell_cell_adhesion_strength', 'cell_BM_adhesion_strength', 'cell_cell_repulsion_strength', 'cell_BM_repulsion_strength', 'cell_adhesion_affinities', 'relative_maximum_adhesion_distance', 'maximum_number_of_attachments', 'attachment_elastic_constant', 'attachment_rate', 'detachment_rate', 'is_motile', 'persistence_time', 'migration_speed', 'migration_bias_direction_x', 'migration_bias_direction_y', 'migration_bias_direction_z', 'migration_bias', 'motility_vector_x', 'motility_vector_y', 'motility_vector_z', 'chemotaxis_index', 'chemotaxis_direction', 'chemotactic_sensitivities', 'secretion_rates', 'uptake_rates', 'saturation_densities', 'net_export_rates', 'internalized_total_substrates', 'fraction_released_at_death', 'fraction_transferred_when_ingested', 'dead_phagocytosis_rate', 'live_phagocytosis_rates', 'attack_rates', 'damage_rate', 'fusion_rates', 'transformation_rates', 'sample']

# %%
print(mcds.get_substrate_names())  # what diffusing substrates?
# Out:
# ['oxygen']

# %%
mcds.data.keys()
# Out:
# dict_keys(['metadata', 'mesh', 'continuum_variables', 'discrete_cells'])

# %% [markdown]
# ## Plot a snapshot of the tumor growth dynamics

# %%
cx = mcds.data['discrete_cells']['position_x']
cy = mcds.data['discrete_cells']['position_y']
cp = mcds.data['discrete_cells']['current_phase']
print(cp)
# Out:
# [2. 2. 2. ... 3. 3. 3.]

# %%
import matplotlib 

# %matplotlib qt 

matplotlib.rc('xtick', labelsize=15) 
matplotlib.rc('ytick', labelsize=15)

plt.scatter( cx, cy, c=cp, s=30 )

plt.axis( 'image' )
plt.axis( [-600,600,-600,600] )

# plt.colorbar()

plt.title( 'Cells colored by current phase', size=20)
plt.xlabel( 'x', size=15 ) 
plt.ylabel( 'y', size=15 )
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Compute the number of each tumor cell phenotype

# %%
# CELL CYCLE MODELS
### advanced_Ki67_cycle_model = 0
### basic_Ki67_cycle_model = 1
### flow_cytometry_cycle_model = 2
### live_apoptotic_cycle_model = 3
### total_cells_cycle_model = 4
### live_cells_cycle_model = 5 
### flow_cytometry_separated_cycle_model = 6
### cycling_quiescent_model = 7
cycle_model = 1

# %%
cp = cp.astype( int )

# CYCLE PHASES
### Ki67_positive_premitotic = 0 
### Ki67_positive_postmitotic = 1 
### Ki67_positive = 2
### Ki67_negative = 3 
### G0G1_phase = 4
### G0_phase = 5
### G1_phase = 6 
### G1a_phase = 7 
### G1b_phase = 8
### G1c_phase = 9
### S_phase = 10
### G2M_phase = 11
### G2_phase = 12
### M_phase = 13
### live = 14

### G1pm_phase = 15
### G1ps_phase = 16 

### cycling = 17 
### quiescent = 18 
if cycle_model == 0:
    Ki67_negative = np.argwhere( cp == 3 ).flatten()
    Ki67_positive_premitotic = np.argwhere( cp == 0 ).flatten()
    Ki67_positive_postmitotic = np.argwhere( cp == 1 ).flatten()
    
    n_Ki67_negative = len( Ki67_negative )
    n_Ki67_positive_premitotic = len( Ki67_positive_premitotic )
    n_Ki67_positive_postmitotic = len( Ki67_positive_postmitotic )
    
    print("Ki67_negative = " + str(n_Ki67_negative))
    print("Ki67_positive_premitotic = " + str(n_Ki67_positive_premitotic))
    print("Ki67_positive_postmitotic = " + str(n_Ki67_positive_postmitotic))
elif cycle_model == 1:
    Ki67_negative = np.argwhere( cp == 3 ).flatten()
    Ki67_positive = np.argwhere( cp == 2 ).flatten()
    
    n_Ki67_negative = len( Ki67_negative )
    n_Ki67_positive = len( Ki67_positive )
    
    print("Ki67_negative = " + str(n_Ki67_negative))
    print("Ki67_positive = " + str(n_Ki67_positive))
elif cycle_model == 2:
    G0G1_phase = np.argwhere( cp == 4 ).flatten()
    S_phase = np.argwhere( cp == 10 ).flatten()
    G2M_phase = np.argwhere( cp == 11 ).flatten()
    
    n_G0G1_phase = len( G0G1_phase )
    n_S_phase = len( S_phase )
    n_G2M_phase = len( G2M_phase )
    
    print("G0G1_phase = " + str(n_G0G1_phase))
    print("S_phase = " + str(n_S_phase))
    print("G2M_phase = " + str(n_G2M_phase))
elif cycle_model == 5:
    live = np.argwhere( cp == 14 ).flatten()
    
    n_live = len( live )
    
    print("live = " + str(n_live))
elif cycle_model == 6:
    G0G1_phase = np.argwhere( cp == 4 ).flatten()
    S_phase = np.argwhere( cp == 10 ).flatten()
    G2_phase = np.argwhere( cp == 12 ).flatten()
    M_phase = np.argwhere( cp == 13 ).flatten()
    
    n_G0G1_phase = len( G0G1_phase )
    n_S_phase = len( S_phase )
    n_G2_phase = len( G2_phase )
    n_M_phase = len( M_phase )
    
    print("G0G1_phase = " + str(n_G0G1_phase))
    print("S_phase = " + str(n_S_phase))
    print("G2_phase = " + str(n_G2_phase))
    print("M_phase = " + str(n_M_phase))
else:
    print("Unrecognized cell cycle model.")
# Out:
# Ki67_negative = 1923
# Ki67_positive = 3708

# %%
# DEATH PHASES
### apoptotic = 100
### necrotic_swelling = 101
### necrotic_lysed = 102
### necrotic = 103 
### debris = 104
apoptotic = np.argwhere( cp == 100 ).flatten()
necrotic = np.argwhere( cp == 103 ).flatten()

n_apoptotic = len( apoptotic )
n_necrotic = len( necrotic )

print("apoptotic = " + str(n_apoptotic))
print("necrotic = " + str(n_necrotic))
# Out:
# apoptotic = 0
# necrotic = 0

# %% [markdown]
# ## Plot a snapshot of the oxygen dispersion dynamics

# %%
o2 = mcds.get_concentrations( 'oxygen' );
X,Y = mcds.get_2D_mesh(); 

plt.clf()
plt.contourf(X, Y, o2[:,:,0]);
plt.colorbar()
plt.axis('image')

plt.title( 'Oxygen concentration', size=20)
plt.xlabel( 'x', size=15 ) 
plt.ylabel( 'y', size=15 )
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# # Plot a snapshot of both tumor cell and oxygen dispersion dynamics

# %%
circle_size = 5

t = mcds.get_time();
o2 = mcds.get_concentrations( 'oxygen' );
X,Y = mcds.get_2D_mesh();

plt.clf()
plt.contourf(X, Y, o2[:,:,0], cmap='spring');
plt.colorbar()

if cycle_model == 0:
    plt.scatter( cx[Ki67_negative], cy[Ki67_negative], s=circle_size);
    plt.scatter( cx[Ki67_positive_premitotic], cy[Ki67_positive_premitotic], s=circle_size);
    plt.scatter( cx[Ki67_positive_postmitotic], cy[Ki67_positive_postmitotic], s=circle_size);
elif cycle_model == 1:
    plt.scatter( cx[Ki67_negative], cy[Ki67_negative], s=circle_size);
    plt.scatter( cx[Ki67_positive], cy[Ki67_positive], s=circle_size);
elif cycle_model == 2:
    plt.scatter( cx[G0G1_phase], cy[G0G1_phase], s=circle_size);
    plt.scatter( cx[S_phase], cy[S_phase], s=circle_size);
    plt.scatter( cx[G2M_phase], cy[G2M_phase], s=circle_size);
elif cycle_model == 5:
    plt.scatter( cx[live], cy[live], s=circle_size);
elif cycle_model == 6:
    plt.scatter( cx[G0G1_phase], cy[G0G1_phase], s=circle_size);
    plt.scatter( cx[S_phase], cy[S_phase], s=circle_size);
    plt.scatter( cx[G2_phase], cy[G2_phase], s=circle_size);
    plt.scatter( cx[M_phase], cy[M_phase], s=circle_size);
else:
    print("Unrecognized cell cycle model.")
plt.scatter( cx[apoptotic], cy[apoptotic], s=circle_size);
plt.scatter( cx[necrotic], cy[necrotic], s=circle_size);

plt.axis('image')
plt.axis([-500, 500, -500, 500])
plt.title( 'Cells colored by current phase at t=' +str(int(t/60)) + ' hr', size=20)
plt.xlabel( 'x', size=15 ) 
plt.ylabel( 'y', size=15 )
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Compute the number of each tumor cell phenotype over all simulation times

# %%
last_index = 120;

times = np.zeros( last_index+1 ); 
if cycle_model == 0:
    Ki67_negative_count = np.zeros( last_index+1 ); 
    Ki67_positive_premitotic_count = np.zeros( last_index+1 ); 
    Ki67_positive_postmitotic_count = np.zeros( last_index+1 ); 
elif cycle_model == 1:
    Ki67_negative_count = np.zeros( last_index+1 ); 
    Ki67_positive_count = np.zeros( last_index+1 ); 
elif cycle_model == 2:
    G0G1_phase_count = np.zeros( last_index+1 ); 
    S_phase_count = np.zeros( last_index+1 ); 
    G2M_phase_count = np.zeros( last_index+1 ); 
elif cycle_model == 5:
    live_count = np.zeros( last_index+1 ); 
elif cycle_model == 6:
    G0G1_phase_count = np.zeros( last_index+1 ); 
    S_phase_count = np.zeros( last_index+1 ); 
    G2_phase_count = np.zeros( last_index+1 ); 
    M_phase_count = np.zeros( last_index+1 ); 
else:
    print("Unrecognized cell cycle model.")
apoptotic_count = np.zeros( last_index+1 ); 
necrotic_count = np.zeros( last_index+1 ); 

for n in range( 0, last_index+1 ):
    filename = 'output'+"%08i"%n+'.xml'
    mcds = pyMCDS(filename, 'output')
    
    times[n] = mcds.get_time()
    cp = mcds.data['discrete_cells']['current_phase']
    if cycle_model == 0:
        Ki67_negative = np.argwhere( cp == 3 ).flatten()
        Ki67_positive_premitotic = np.argwhere( cp == 0 ).flatten()
        Ki67_positive_postmitotic = np.argwhere( cp == 1 ).flatten()

        Ki67_negative_count[n] = len( Ki67_negative )
        Ki67_positive_premitotic_count[n] = len( Ki67_positive_premitotic )
        Ki67_positive_postmitotic_count[n] = len( Ki67_positive_postmitotic )
    elif cycle_model == 1:
        Ki67_negative = np.argwhere( cp == 3 ).flatten()
        Ki67_positive = np.argwhere( cp == 2 ).flatten()

        Ki67_negative_count[n] = len( Ki67_negative )
        Ki67_positive_count[n] = len( Ki67_positive )
    elif cycle_model == 2:
        G0G1_phase = np.argwhere( cp == 4 ).flatten()
        S_phase = np.argwhere( cp == 10 ).flatten()
        G2M_phase = np.argwhere( cp == 11 ).flatten()

        G0G1_phase_count[n] = len( G0G1_phase )
        S_phase_count[n] = len( S_phase )
        G2M_phase_count[n] = len( G2M_phase )
    elif cycle_model == 5:
        live = np.argwhere( cp == 14 ).flatten()

        live_count[n] = len( live )
    elif cycle_model == 6:
        G0G1_phase = np.argwhere( cp == 4 ).flatten()
        S_phase = np.argwhere( cp == 10 ).flatten()
        G2_phase = np.argwhere( cp == 12 ).flatten()
        M_phase = np.argwhere( cp == 13 ).flatten()

        G0G1_phase_count[n] = len( G0G1_phase )
        S_phase_count[n] = len( S_phase )
        G2_phase_count[n] = len( G2_phase )
        M_phase_count[n] = len( M_phase )
    else:
        print("Unrecognized cell cycle model.")
    apoptotic = np.argwhere( cp == 100 ).flatten()
    necrotic = np.argwhere( cp == 103 ).flatten()

    apoptotic_count[n] = len( apoptotic )
    necrotic_count[n] = len( necrotic )
# Out:
# Reading output/output00000000.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000000_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000000_cells.mat
# Reading output/output00000001.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000001_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000001_cells.mat
# Reading output/output00000002.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000002_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000002_cells.mat
# Reading output/output00000003.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000003_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000003_cells.mat
# Reading output/output00000004.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000004_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000004_cells.mat
# Reading output/output00000005.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000005_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000005_cells.mat
# Reading output/output00000006.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000006_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000006_cells.mat
# Reading output/output00000007.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000007_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000007_cells.mat
# Reading output/output00000008.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000008_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000008_cells.mat
# Reading output/output00000009.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000009_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000009_cells.mat
# Reading output/output00000010.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000010_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000010_cells.mat
# Reading output/output00000011.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000011_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000011_cells.mat
# Reading output/output00000012.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000012_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000012_cells.mat
# Reading output/output00000013.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000013_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000013_cells.mat
# Reading output/output00000014.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000014_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000014_cells.mat
# Reading output/output00000015.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000015_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000015_cells.mat
# Reading output/output00000016.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000016_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000016_cells.mat
# Reading output/output00000017.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000017_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000017_cells.mat
# Reading output/output00000018.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000018_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000018_cells.mat
# Reading output/output00000019.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000019_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000019_cells.mat
# Reading output/output00000020.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000020_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000020_cells.mat
# Reading output/output00000021.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000021_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000021_cells.mat
# Reading output/output00000022.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000022_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000022_cells.mat
# Reading output/output00000023.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000023_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000023_cells.mat
# Reading output/output00000024.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000024_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000024_cells.mat
# Reading output/output00000025.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000025_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000025_cells.mat
# Reading output/output00000026.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000026_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000026_cells.mat
# Reading output/output00000027.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000027_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000027_cells.mat
# Reading output/output00000028.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000028_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000028_cells.mat
# Reading output/output00000029.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000029_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000029_cells.mat
# Reading output/output00000030.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000030_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000030_cells.mat
# Reading output/output00000031.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000031_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000031_cells.mat
# Reading output/output00000032.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000032_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000032_cells.mat
# Reading output/output00000033.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000033_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000033_cells.mat
# Reading output/output00000034.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000034_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000034_cells.mat
# Reading output/output00000035.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000035_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000035_cells.mat
# Reading output/output00000036.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000036_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000036_cells.mat
# Reading output/output00000037.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000037_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000037_cells.mat
# Reading output/output00000038.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000038_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000038_cells.mat
# Reading output/output00000039.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000039_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000039_cells.mat
# Reading output/output00000040.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000040_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000040_cells.mat
# Reading output/output00000041.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000041_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000041_cells.mat
# Reading output/output00000042.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000042_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000042_cells.mat
# Reading output/output00000043.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000043_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000043_cells.mat
# Reading output/output00000044.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000044_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000044_cells.mat
# Reading output/output00000045.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000045_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000045_cells.mat
# Reading output/output00000046.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000046_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000046_cells.mat
# Reading output/output00000047.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000047_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000047_cells.mat
# Reading output/output00000048.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000048_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000048_cells.mat
# Reading output/output00000049.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000049_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000049_cells.mat
# Reading output/output00000050.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000050_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000050_cells.mat
# Reading output/output00000051.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000051_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000051_cells.mat
# Reading output/output00000052.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000052_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000052_cells.mat
# Reading output/output00000053.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000053_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000053_cells.mat
# Reading output/output00000054.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000054_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000054_cells.mat
# Reading output/output00000055.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000055_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000055_cells.mat
# Reading output/output00000056.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000056_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000056_cells.mat
# Reading output/output00000057.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000057_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000057_cells.mat
# Reading output/output00000058.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000058_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000058_cells.mat
# Reading output/output00000059.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000059_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000059_cells.mat
# Reading output/output00000060.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000060_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000060_cells.mat
# Reading output/output00000061.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000061_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000061_cells.mat
# Reading output/output00000062.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000062_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000062_cells.mat
# Reading output/output00000063.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000063_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000063_cells.mat
# Reading output/output00000064.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000064_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000064_cells.mat
# Reading output/output00000065.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000065_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000065_cells.mat
# Reading output/output00000066.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000066_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000066_cells.mat
# Reading output/output00000067.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000067_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000067_cells.mat
# Reading output/output00000068.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000068_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000068_cells.mat
# Reading output/output00000069.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000069_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000069_cells.mat
# Reading output/output00000070.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000070_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000070_cells.mat
# Reading output/output00000071.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000071_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000071_cells.mat
# Reading output/output00000072.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000072_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000072_cells.mat
# Reading output/output00000073.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000073_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000073_cells.mat
# Reading output/output00000074.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000074_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000074_cells.mat
# Reading output/output00000075.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000075_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000075_cells.mat
# Reading output/output00000076.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000076_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000076_cells.mat
# Reading output/output00000077.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000077_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000077_cells.mat
# Reading output/output00000078.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000078_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000078_cells.mat
# Reading output/output00000079.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000079_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000079_cells.mat
# Reading output/output00000080.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000080_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000080_cells.mat
# Reading output/output00000081.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000081_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000081_cells.mat
# Reading output/output00000082.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000082_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000082_cells.mat
# Reading output/output00000083.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000083_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000083_cells.mat
# Reading output/output00000084.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000084_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000084_cells.mat
# Reading output/output00000085.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000085_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000085_cells.mat
# Reading output/output00000086.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000086_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000086_cells.mat
# Reading output/output00000087.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000087_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000087_cells.mat
# Reading output/output00000088.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000088_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000088_cells.mat
# Reading output/output00000089.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000089_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000089_cells.mat
# Reading output/output00000090.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000090_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000090_cells.mat
# Reading output/output00000091.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000091_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000091_cells.mat
# Reading output/output00000092.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000092_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000092_cells.mat
# Reading output/output00000093.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000093_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000093_cells.mat
# Reading output/output00000094.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000094_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000094_cells.mat
# Reading output/output00000095.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000095_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000095_cells.mat
# Reading output/output00000096.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000096_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000096_cells.mat
# Reading output/output00000097.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000097_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000097_cells.mat
# Reading output/output00000098.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000098_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000098_cells.mat
# Reading output/output00000099.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000099_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000099_cells.mat
# Reading output/output00000100.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000100_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000100_cells.mat
# Reading output/output00000101.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000101_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000101_cells.mat
# Reading output/output00000102.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000102_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000102_cells.mat
# Reading output/output00000103.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000103_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000103_cells.mat
# Reading output/output00000104.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000104_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000104_cells.mat
# Reading output/output00000105.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000105_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000105_cells.mat
# Reading output/output00000106.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000106_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000106_cells.mat
# Reading output/output00000107.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000107_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000107_cells.mat
# Reading output/output00000108.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000108_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000108_cells.mat
# Reading output/output00000109.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000109_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000109_cells.mat
# Reading output/output00000110.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000110_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000110_cells.mat
# Reading output/output00000111.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000111_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000111_cells.mat
# Reading output/output00000112.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000112_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000112_cells.mat
# Reading output/output00000113.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000113_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000113_cells.mat
# Reading output/output00000114.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000114_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000114_cells.mat
# Reading output/output00000115.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000115_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000115_cells.mat
# Reading output/output00000116.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000116_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000116_cells.mat
# Reading output/output00000117.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000117_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000117_cells.mat
# Reading output/output00000118.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000118_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000118_cells.mat
# Reading output/output00000119.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000119_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000119_cells.mat
# Reading output/output00000120.xml
# Reading output/initial_mesh0.mat
# Reading output/output00000120_microenvironment0.mat
# Parsing oxygen data
# working on discrete cell data...
#
# Reading output/output00000120_cells.mat

# %% [markdown]
# ## Plot the temporal evolution of the number of tumor cells

# %%
plt.clf()
plt.plot( times, apoptotic_count , '-', label='Apoptotic' ); 
plt.plot( times, necrotic_count , '-', label='Necrotic' ); 
if cycle_model == 0:
    plt.plot( times, Ki67_negative_count , '-', label=r'Ki67$^{-}$' );
    plt.plot( times, Ki67_positive_premitotic_count , '-', label=r'Ki67$^{+}$ (pre)' );
    plt.plot( times, Ki67_positive_postmitotic_count , '-', label=r'Ki67$^{+}$ (post)' );
elif cycle_model == 1:
    plt.plot( times, Ki67_negative_count , '-', label=r'Ki67$^{-}$' );
    plt.plot( times, Ki67_positive_count , '-', label=r'Ki67$^{+}$' );
elif cycle_model == 2:
    plt.plot( times, G0G1_phase_count , '-', label='G0/G1' );
    plt.plot( times, S_phase_count , '-', label='S' );
    plt.plot( times, G2M_phase_count , '-', label='G2/M' );
elif cycle_model == 5:
    plt.plot( times, live_count , '-', label='Live' );
elif cycle_model == 6:
    plt.plot( times, G0G1_phase_count , '-', label='G0/G1' );
    plt.plot( times, S_phase_count , '-', label='S' );
    plt.plot( times, G2_phase_count , '-', label='G2' );
    plt.plot( times, M_phase_count , '-', label='M' );
else:
    print("Unrecognized cell cycle model.")
plt.legend()

plt.title( 'Temporal evolution of the number of tumor cells', size=20)
plt.xlabel( 'Time', size=15 ) 
plt.ylabel( 'Number of cells', size=15 )
# Out:
# Text(0, 0.5, 'Number of cells')

# %% [markdown]
# ## Compute growth rate of the live cells

# %%
if cycle_model == 0:
    poly = np.polyfit( times, np.log(Ki67_negative_count + Ki67_positive_premitotic_count + Ki67_positive_postmitotic_count), 1) 
elif cycle_model == 1:
    poly = np.polyfit( times, np.log(Ki67_negative_count + Ki67_positive_count), 1) 
elif cycle_model == 2:
    poly = np.polyfit( times, np.log(G0G1_phase_count + S_phase_count + G2M_phase_count), 1) 
elif cycle_model == 5:
    poly = np.polyfit( times, np.log(live_count), 1) 
elif cycle_model == 6:
    poly = np.polyfit( times, np.log(G0G1_phase_count + S_phase_count + G2_phase_count + M_phase_count), 1) 
else:
    print("Unrecognized cell cycle model.")
print( poly[0] )
# growth rate is 0th element
# in units of 1/min
# Out:
# 0.000713514510106747
